# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/vknsr/Downloads/archive (1)/credit_risk_dataset.csv")

# %%
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
dup=df.duplicated()

# %%
df[dup]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32576    False
# 32577    False
# 32578    False
# 32579    False
# 32580    False
# Length: 32416, dtype: bool

# %%
df=df.drop(['cb_person_default_on_file','cb_person_cred_hist_length','loan_grade'],axis=1)

# %%
df=df.drop(['loan_int_rate'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('loan_status',axis=1),df['loan_status'],random_state=0,test_size=0.2,stratify=df['loan_status'],shuffle=True)

# %%
df['loan_status'].value_counts()
# Out:
# 0    25327
# 1     7089
# Name: loan_status, dtype: int64

# %%
x_train[['person_income','loan_amnt','loan_percent_income']].head()
# Out:
#        person_income  loan_amnt  loan_percent_income
# 21415          48000      10000                 0.21
# 12916          85000       7500                 0.09
# 2938          125000       3000                 0.02
# 19114          62000       2300                 0.04
# 6057           48000       4200                 0.09

# %%
x_train.drop('loan_percent_income',axis=1,inplace=True)
x_test.drop('loan_percent_income',axis=1,inplace=True)

# %%
x=x_train.loc[x_train['person_age']<80,:]
x
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 21415          33          48000                   OWN               11.0
# 12916          25          85000              MORTGAGE                5.0
# 2938           26         125000                  RENT               10.0
# 19114          29          62000                  RENT                4.0
# 6057           24          48000              MORTGAGE                4.0
# ...           ...            ...                   ...                ...
# 23921          29          67422              MORTGAGE               13.0
# 27783          29         195000              MORTGAGE                5.0
# 24358          27          72000                   OWN                2.0
# 2544           23          30000                  RENT                0.0
# 6848           24          50000              MORTGAGE                4.0
#
#              loan_intent  loan_amnt
# 21415    HOMEIMPROVEMENT      10000
# ...

# %%
x=x.loc[(x['person_emp_length']<66) | (x['person_emp_length'].isna()),:]

# %%
y=y_train[x.index]

# %%
num_cols = [col for col in x if x[col].dtypes != 'O']
num_cols
# Out:
# ['person_age', 'person_income', 'person_emp_length', 'loan_amnt']

# %%
cat_cols = [col for col in x if x[col].dtypes == 'O']
cat_cols
# Out:
# ['person_home_ownership', 'loan_intent']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
num_pipe = Pipeline([
    ('impute', IterativeImputer()),
    ('scale', StandardScaler()),
])
ct = ColumnTransformer([
    ('num_pipe', num_pipe, num_cols),
    ('cat_cols', OneHotEncoder(sparse=False, handle_unknown='ignore'), cat_cols)
], remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor 
import lightgbm
from lightgbm import LGBMClassifier

# %%
# !pip install lightgbm

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
grid = {
    RandomForestClassifier(random_state=0, n_jobs=-1, class_weight='balanced'):
    {'model__n_estimators':[300,400,500],
     'coltf__num_pipe__impute__estimator': [LinearRegression(), RandomForestRegressor(random_state=0),
                                        KNeighborsRegressor()]},
    
    LGBMClassifier(class_weight='balanced', random_state=0, n_jobs=-1):
    {'model__n_estimators':[300,400,500],
     'model__learning_rate':[0.001,0.01,0.1,1,10],
     'model__boosting_type': ['gbdt', 'goss', 'dart'],
     'coltf__num_pipe__impute__estimator':[LinearRegression(), RandomForestRegressor(random_state=0),
                                        KNeighborsRegressor()]},
}

# %%
for clf, param in grid.items():
    print(clf)
    print('-'*50)
    print(param)
    print('\n')
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0)
# --------------------------------------------------
# {'model__n_estimators': [300, 400, 500], 'coltf__num_pipe__impute__estimator': [LinearRegression(), RandomForestRegressor(random_state=0), KNeighborsRegressor()]}
#
#
# LGBMClassifier(class_weight='balanced', random_state=0)
# --------------------------------------------------
# {'model__n_estimators': [300, 400, 500], 'model__learning_rate': [0.001, 0.01, 0.1, 1, 10], 'model__boosting_type': ['gbdt', 'goss', 'dart'], 'coltf__num_pipe__impute__estimator': [LinearRegression(), RandomForestRegressor(random_state=0), KNeighborsRegressor()]}

# %%
full_df = pd.DataFrame()
best_algos = {}

for clf, param in grid.items():
    pipe = Pipeline([
    ('coltf', ct),
    ('model', clf)
])

    rs = RandomizedSearchCV(estimator=pipe, param_distributions=param, scoring='accuracy',
                            n_jobs=-1, verbose=3, n_iter=4, random_state=0)
    
    rs.fit(x, y)
    
    all_res = pd.DataFrame(rs.cv_results_)

    temp = all_res.loc[:, ['params', 'mean_test_score']]
    algo_name = str(clf).split('(')[0]
    temp['algo'] = algo_name
    
    full_df = pd.concat([full_df, temp], ignore_index=True)
    best_algos[algo_name] = rs.best_estimator_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\vknsr\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\vknsr\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
full_df.sort_values('mean_test_score', ascending=False)
# Out:
#                                               params  mean_test_score  \
# 2  {'model__n_estimators': 400, 'coltf__num_pipe_...         0.872850
# 1  {'model__n_estimators': 500, 'coltf__num_pipe_...         0.872772
# 0  {'model__n_estimators': 400, 'coltf__num_pipe_...         0.872657
# 3  {'model__n_estimators': 400, 'coltf__num_pipe_...         0.872387
# 7  {'model__n_estimators': 300, 'model__learning_...         0.837513
# 5  {'model__n_estimators': 300, 'model__learning_...         0.812476
# 6  {'model__n_estimators': 300, 'model__learning_...         0.796043
# 4  {'model__n_estimators': 300, 'model__learning_...         0.792841
#
#                      algo
# 2  RandomForestClassifier
# 1  RandomForestClassifier
# 0  RandomForestClassifier
# 3  RandomForestClassifier
# 7          LGBMClassifier
# 5          LGBMClassifier
# 6          LGBMClassifier
# 4          LGBMClassifier

# %%
full_df.sort_values('mean_test_score', ascending=False).iloc[0, 0]
# Out:
# {'model__n_estimators': 400,
#  'coltf__num_pipe__impute__estimator': LinearRegression()}

# %%
be = best_algos['RandomForestClassifier']
be
# Out:
# Pipeline(steps=[('coltf',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_pipe',
#                                                   Pipeline(steps=[('impute',
#                                                                    IterativeImputer(estimator=LinearRegression())),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['person_age',
#                                                    'person_income',
#                                                    'person_emp_length',
#                                                    'loan_amnt']),
#                                                  ('cat_cols',
#                                                   OneHotEncoder(handle_unknown='ignore',
# ...

# %%
be.fit(x, y)
# Out:
# C:\Users\vknsr\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('coltf',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_pipe',
#                                                   Pipeline(steps=[('impute',
#                                                                    IterativeImputer(estimator=LinearRegression())),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['person_age',
#                                                    'person_income',
# ...

# %%
preds=be.predict(x_test)
preds
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,  classification_report
confusion_matrix(y_test, preds)
# Out:
# array([[4917,  149],
#        [ 711,  707]], dtype=int64)

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      5066
#            1       0.83      0.50      0.62      1418
#
#     accuracy                           0.87      6484
#    macro avg       0.85      0.73      0.77      6484
# weighted avg       0.86      0.87      0.85      6484

# %%
be.score(x_test, y_test)
# Out:
# 0.8673658235657001

# %%
x_test
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 31162          44          80000              MORTGAGE               14.0
# 17831          24          38000                  RENT                0.0
# 21226          33         113800                  RENT                8.0
# 8789           22          60000              MORTGAGE                2.0
# 5717           23          38000                  RENT                1.0
# ...           ...            ...                   ...                ...
# 22219          32          53408              MORTGAGE                8.0
# 8175           25          42000                  RENT                0.0
# 29915          42         100000                  RENT                3.0
# 480            24          18000              MORTGAGE                3.0
# 27333          34         121000              MORTGAGE                8.0
#
#            loan_intent  loan_amnt
# 31162          MEDICAL      10000
# ...

# %%
import pickle

# %%
pickle.dump(be,open('model.pkl','wb'))

# %%
loaded_model = pickle.load(open('model.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.8673658235657001
